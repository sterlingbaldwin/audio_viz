# %%
import pyaudio
import wave
import numpy as np
from scipy import signal
from scipy.io import wavfile
import matplotlib.pyplot as plt

# %%
chunk = 1024  # Record in chunks of 1024 samples
sample_format = pyaudio.paInt32  # 16 bits per sample
channels = 1
fs = 44100  # Record at 44100 samples per second
seconds = 1
filename = "sample.wav"

p = pyaudio.PyAudio()  # Create an interface to PortAudio

print('Recording')

stream = p.open(format=sample_format,
                channels=channels,
                rate=fs,
                frames_per_buffer=chunk,
                input=True)

frames = []  # Initialize array to store frames

# Store data in chunks for 3 seconds
for i in range(0, int(fs / chunk * seconds)):
    data = stream.read(chunk)
    frames.append(data)

# Stop and close the stream 
stream.stop_stream()
stream.close()
# Terminate the PortAudio interface
p.terminate()

# Save the recorded data as a WAV file
wf = wave.open(filename, 'wb')
wf.setnchannels(channels)
wf.setsampwidth(p.get_sample_size(sample_format))
wf.setframerate(fs)
wf.writeframes(b''.join(frames))
wf.close()

rate, data = wavfile.read('sample.wav') # See source

# Compute PSD:
f, P = signal.periodogram(data, rate) # Frequencies and PSD

# Display PSD:
fig, axe = plt.subplots()
axe.semilogy(f, P)
axe.set_xlim([0,500])
axe.set_ylim([1e-8, 1e10])
axe.set_xlabel(r'Frequency, $\nu$ $[\mathrm{Hz}]$')
axe.set_ylabel(r'PSD, $P$ $[\mathrm{AU^2Hz}^{-1}]$')
axe.set_title('Periodogram')
axe.grid(which='both')
# Out:
# Recording

# %%
idx = signal.find_peaks(P, height=1e-2)[0][0]
f[idx] # 440.0 Hz
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [148], in <module>
# ----> 1 idx = signal.find_peaks(P, height=1e-2)[0][0]
#       2 f[idx]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'find_peaks'

# %%
stream = p.open(format=sample_format,
                channels=channels,
                rate=fs,
                frames_per_buffer=chunk,
                input=True)

frames = []  # Initialize array to store frames

# Store data in chunks for 3 seconds
for i in range(0, int(fs / chunk * seconds)):
    data = stream.read(chunk)
    frames.append(data)

# Stop and close the stream 
stream.stop_stream()
stream.close()
# Terminate the PortAudio interface
p.terminate()

audio_data = np.ndarray((len(frames), fs))

np.fromstring(data, dtype=np.int16)

# Compute PSD:
f, P = signal.periodogram(audio_data, rate) # Frequencies and PSD

# Display PSD:
fig, axe = plt.subplots()
axe.semilogy(audio_data)
axe.set_xlim([0,500])
axe.set_ylim([1e-8, 1e10])
axe.set_xlabel(r'Frequency, $\nu$ $[\mathrm{Hz}]$')
axe.set_ylabel(r'PSD, $P$ $[\mathrm{AU^2Hz}^{-1}]$')
axe.set_title('Periodogram')
axe.grid(which='both')

# %%
audio_data = np.ndarray((len(frames), chunk))
print(audio_data.shape)

for idx, frame in enumerate(frames):
    audio_data[idx] = np.fromstring(data, dtype=np.int16)

# Compute PSD:
f, t, Sxx = signal.spectrogram(audio_data[0])

plt.pcolormesh(t, f, Sxx)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# (43, 1024)
# /var/folders/q2/783ycvt547bgbd7ny9mwqs3r0000gn/T/ipykernel_2752/2855988993.py:5: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   audio_data[idx] = np.fromstring(data, dtype=np.int16)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [149], in <module>
#       2 print(audio_data.shape)
#       4 for idx, frame in enumerate(frames):
# ----> 5     audio_data[idx] = np.fromstring(data, dtype=np.int16)
#       7 # Compute PSD:
#       8 f, t, Sxx = signal.spectrogram(audio_data[0])
#
# ValueError: could not broadcast input array from shape (88064,) into shape (1024,)

# %%
f.shape
# Out:
# (129,)

# %%
t.shape
# Out:
# (4,)

# %%
Sxx.shape
# Out:
# (129, 4)

# %%
from scipy import signal

from scipy.fft import fftshift

import matplotlib.pyplot as plt

rng = np.random.default_rng()
fs = 10e3

N = 1e5

amp = 2 * np.sqrt(2)

noise_power = 0.01 * fs / 2

time = np.arange(N) / float(fs)

mod = 500*np.cos(2*np.pi*0.25*time)

carrier = amp * np.sin(2*np.pi*3e3*time + mod)

noise = rng.normal(scale=np.sqrt(noise_power), size=time.shape)

noise *= np.exp(-time/5)

x = carrier + noise
f, t, Sxx = signal.spectrogram(x, fs)

plt.pcolormesh(t, f, Sxx, shading='gouraud')

plt.ylabel('Frequency [Hz]')

plt.xlabel('Time [sec]')

plt.show()

# %%
f.shape
# Out:
# (129,)

# %%
t.shape
# Out:
# (446,)

# %%
Sxx.shape
# Out:
# (129, 446)

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys


spf = wave.open("sample.wav", "r")

spf.setpos(10000)
# Extract Raw Audio from Wav File
signal = spf.readframes(1000)
signal = np.frombuffer(signal, np.int32)


# If Stereo
if spf.getnchannels() == 2:
    print("Just mono files")
    sys.exit(0)

plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()

# %%
signal.shape
# Out:
# (1000,)

# %%
from scipy import signal
spf = wave.open("sample.wav", "r")

spf.setpos(10000)
# Extract Raw Audio from Wav File
data = spf.readframes(10000)
data = np.frombuffer(data, np.int32)

f, t, Sxx = signal.spectrogram(data)
plt.pcolormesh(t, f, Sxx, shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [usec]')
plt.show()

# %%
data
# Out:
# array([-838159999, -776984063, -711889535, ...,  153178335,   65818200,
#         -21917900], dtype=int32)

# %%
import matplotlib.pyplot as plt
# from scipy.fftpack import fft
# from scipy.fft import fftfreq
from numpy.fft import fft
from numpy.fft import fftfreq
# from scipy.io import wavfile # get the api
# fs, data = wavfile.read('sample.wav') # load the data
# a = data.T[0] # this is a two channel soundtrack, I get the first track
# b = [(ele/2**8.)*2-1 for ele in a] # this is 8-bit track, b is now normalized on [-1,1)

spf = wave.open("sample3.wav", "r")

# spf.setpos(10000)
# Extract Raw Audio from Wav File
data = spf.readframes(-1)
data = np.frombuffer(data, np.int32)

w = fft(data)
freqs = fftfreq(len(w))

idx = np.argmax(np.abs(w))
freq = freqs[idx]
freq_in_hertz = abs(freq * fs)
print(freq_in_hertz)


# freq = fftfreq(data, d=1/fs) # calculate fourier transform (complex numbers list)
# d = len(c)//2  # you only need half of the fft list (real signal symmetry)
# # plt.pcolormesh(t, f, abs(z)) 
# plt.plot(freq)
# plt.show()
# Out:
# 775.1953125

# %%
z[:,0].shape
# Out:
# (129,)

# %%
np.argmax(abs(c[:d]))
# Out:
# 522

# %%
c.index(max(abs(c[:d])))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [183], in <module>
# ----> 1 c.index(max(abs(c[:d])))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
chunk = 1024  # Record in chunks of 1024 samples
sample_format = pyaudio.paInt32  # 16 bits per sample
channels = 1
fs = 44100  # Record at 44100 samples per second

p = pyaudio.PyAudio()  # Create an interface to PortAudio
stream = p.open(format=sample_format,
                channels=1,
                rate=fs,
                frames_per_buffer=chunk,
                input=True)

samples_to_toss = 10
for i in range(samples_to_toss):
    data = stream.read(chunk)

    
while True:
    data = stream.read(chunk)
    data = np.frombuffer(data, np.int32)
    c = fft(data) # calculate fourier transform (complex numbers list)
    d = len(c)//2
    m = np.argmax(abs(c[d:]))
    plt.pause(abs(c[d:]), 'r')
# data = [stream.read(chunk)]


# wf = wave.open("sample3.wav", 'wb')
# wf.setnchannels(channels)
# wf.setsampwidth(p.get_sample_size(sample_format))
# wf.setframerate(fs)
# wf.writeframes(b''.join(data))
# wf.close()

# rate, data = wavfile.read('sample3.wav') # See source

data = np.frombuffer(data, np.int32)

c = fft(data) # calculate fourier transform (complex numbers list)
d = len(c)//2
print(f"freq = {np.argmax(abs(c[d:]))}")

stream.stop_stream()
stream.close()
# Terminate the PortAudio interface
p.terminate()

plt.plot(abs(c[d:]), 'r') 
plt.show()
# Out:
# freq = 494

# %%
p = pyaudio.PyAudio()  # Create an interface to PortAudio
stream = p.open(format=sample_format,
                channels=1,
                rate=fs,
                input=True)

# samples_to_toss = 10
# for i in range(samples_to_toss):
#     data = stream.read(chunk)

    
while True:
    data = stream.read(chunk, exception_on_overflow = False)
    data = np.frombuffer(data, np.int32)
    c = fft(data) # calculate fourier transform (complex numbers list)
    d = len(c)//2
    m = np.argmax(abs(c[d:]))
    plt.plot(abs(c[d:]), 'r') 
    plt.pause(0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [237], in <module>
#      16     d = len(c)//2
#      17     m = np.argmax(abs(c[d:]))
# ---> 18     plt.plot(abs(c[d:]), 'r')
#      19     plt.pause(0.2)
#      20 plt.show()
#
# File ~/miniforge3/envs/av/lib/python3.10/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/miniforge3/envs/av/lib/python3.10/site-packages/matplotlib/pyplot.py:2262, in gca(**kwargs)
#    2260 @_copy_docstring_and_deprecators(Figure.gca)
#    2261 def gca(**kwargs):
# -> 2262     return gcf().gca(**kwargs)
#
# ...

# %%
data.shape
# Out:
# (1024,)

# %%
abs(data)
# Out:
# array([ 22336411,  39701576,  45554235, ..., 796215359, 858957182,
#        916597503], dtype=int32)

# %%
np.argmax(abs(c[d:]))
# Out:
# 494

# %%
c
# Out:
# array([1.26943977e+09-0.00000000e+00j, 1.31631691e+09-6.22743606e+08j,
#        1.09284091e+09+1.61537031e+09j, ...,
#        3.94016525e+08+1.03342705e+09j, 1.09284091e+09-1.61537031e+09j,
#        1.31631691e+09+6.22743606e+08j])
